# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
from config import g_key

# Configure gmaps
gmaps.configure(api_key=g_key)

# %%
# 1. Read the WeatherPy_vacation.csv into a DataFrame.
vacation_df = pd.read_csv("Vacation_Search/WeatherPy_vacation.csv")
vacation_df.head()
# Out:
#    City_ID        City Country  Max Temp    Lat     Lng  \
# 0        8        Hilo      US     84.20  19.73 -155.09
# 1       20       Kapaa      US     82.40  22.08 -159.32
# 2       26  Port Blair      IN     83.57  11.67   92.75
# 3       32  Butaritari      KI     82.24   3.07  172.79
# 4       33     Rawlins      US     82.40  41.79 -107.24
#
#                                Hotel Name
# 0                     Hilo Hawaiian Hotel
# 1  Sheraton Kauai Resort at Coconut Beach
# 2               Fortune Resort Bay Island
# 3                      Isles Sunset Lodge
# 4             Holiday Inn Express Rawlins

# %%
# 2. Using the template add the city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# 3a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in clean_hotel_df.iterrows()]

# 3b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = vacation_df[["Lat", "Lng"]]

# %%
# 4a. Add a marker layer for each city to the map.
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
max_temp = clean_hotel_df["Max Temp"]
heat_layer = gmaps.heatmap_layer(locations,dissipating=False,
             max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)

# 4b. Display the figure

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
vacation_df = vacation_df.set_index('City')

# %%
# From the map above pick 4 cities and create a vacation itinerary route to travel between the four cities. 
# 5. Create DataFrames for each city by filtering the 'vacation_df' using the loc method. 
# Hint: The starting and ending city should be the same city.


vacation_start = vacation_df.loc['Evanston']
vacation_end = vacation_df.loc['Evanston']
vacation_stop1 = vacation_df.loc['Half Moon Bay']
vacation_stop2 = vacation_df.loc['Saint Anthony']
vacation_stop3 = vacation_df.loc['Silver City']
                                
vacation_start
# Out:
# City_ID                             521
# Country                              US
# Max Temp                           82.4
# Lat                               42.04
# Lng                              -87.69
# Hotel Name    Hilton Orrington/Evanston
# Name: Evanston, dtype: object

# %%
# 6. Get the latitude-longitude pairs as tuples from each city DataFrame using the to_numpy function and list indexing.
start = vacation_start.to_numpy()[3:5]
end = vacation_end.to_numpy()[3:5]
stop1 = vacation_stop1.to_numpy()[3:5]
stop2 = vacation_stop2.to_numpy()[3:5]
stop3 = vacation_stop3.to_numpy()[3:5]

# %%
v1 = pd.DataFrame(vacation_start)
v1
# Out:
#                              Evanston
# City_ID                           521
# Country                            US
# Max Temp                         82.4
# Lat                             42.04
# Lng                            -87.69
# Hotel Name  Hilton Orrington/Evanston

# %%
# 7. Create a direction layer map using the start and end latitude-longitude pairs,
# and stop1, stop2, and stop3 as the waypoints. The travel_mode should be "DRIVING", "BICYCLING", or "WALKING".
fig = gmaps.figure()
geneva2zurich = gmaps.directions_layer(start, end,waypoints = [stop1, stop2, stop3], travel_mode = 'DRIVING')
fig.add_layer(geneva2zurich)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# 8. To create a marker layer map between the four cities.
#  Combine the four city DataFrames into one DataFrame using the concat() function.

start_df = pd.DataFrame(vacation_start.reset_index())
stop1_df =pd.DataFrame(vacation_stop1.reset_index())
stop2_df= pd.DataFrame(vacation_stop2.reset_index())
stop3_df=pd.DataFrame(vacation_stop3.reset_index())
frames =  [start_df,stop1_df,stop2_df,stop3_df]


itinerary_df = pd.concat(frames,ignore_index=True)

x = pd.DataFrame(itinerary_df)

x
# Out:
#          index                   Evanston                    Half Moon Bay  \
# 0      City_ID                        521                              NaN
# 1      Country                         US                              NaN
# 2     Max Temp                       82.4                              NaN
# 3          Lat                      42.04                              NaN
# 4          Lng                     -87.69                              NaN
# 5   Hotel Name  Hilton Orrington/Evanston                              NaN
# 6      City_ID                        NaN                              355
# 7      Country                        NaN                               US
# 8     Max Temp                        NaN                             80.6
# 9          Lat                        NaN                            37.46
# 10         Lng                        NaN                          -122.43
# ...

# %%
# Out:
#         index                   Evanston
# 0     City_ID                        521
# 1     Country                         US
# 2    Max Temp                       82.4
# 3         Lat                      42.04
# 4         Lng                     -87.69
# 5  Hotel Name  Hilton Orrington/Evanston

# %%
# 9 Using the template add city name, the country code, the weather description and maximum temperature for the city. 
info_box_template = """
<dl>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# 10a Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in itinerary_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = itinerary_df[["Lat", "Lng"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-103-3ad1acde01f2> in <module>
#       9
#      10 # 10a Get the data from each row and add it to the formatting template and store the data in a list.
# ---> 11 hotel_info = [info_box_template.format(**row) for index, row in itinerary_df.iterrows()]
#      12
#      13 # 10b. Get the latitude and longitude from each row and store in a new DataFrame.
#
# <ipython-input-103-3ad1acde01f2> in <listcomp>(.0)
#       9
#      10 # 10a Get the data from each row and add it to the formatting template and store the data in a list.
# ---> 11 hotel_info = [info_box_template.format(**row) for index, row in itinerary_df.iterrows()]
#      12
#      13 # 10b. Get the latitude and longitude from each row and store in a new DataFrame.
#
# KeyError: 'City'

# %%
# 11a. Add a marker layer for each city to the map.

# 11b. Display the figure
